# %%
# Stop-words and punctuation for normalize function
from stop_words import get_stop_words
from string import punctuation

# Oper
import re
import gensim
import pickle
import numpy as np
import pandas as pd
from collections import Counter

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
# %matplotlib inline

# NLTK and pymorphy for normalize function 
from nltk import word_tokenize
from nltk.stem.lancaster import LancasterStemmer
from pymorphy2 import MorphAnalyzer

morph = MorphAnalyzer()

stemmer = LancasterStemmer()

punct = punctuation + '«»—…“”*№–'

stop_words = get_stop_words('russian')

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %% [markdown]
# Создадим функцию нормализации текста для нашей задачи

# %%
def remove_tags(text):
    return re.sub(r'<[^>]+>', '', text)

def normalize(text):
    
    words = [word.strip(punct) for word in remove_tags(text.lower()).split()]
    words = [morph.parse(word)[0] for word in words if word and word not in get_stop_words('russian')]
    words = [stemmer.stem(word.normal_form) for word in words if word.tag.POS == 'NOUN']
            
    return words

# %%
def opt_normalize(texts, top=None):
    uniq = Counter()
    
    for text in texts:
        uniq.update(text)
            
    norm_uniq = {word:normalize(word)[0] for word, _ in uniq.most_common(top)}
    
    norm_texts = []
    for text in texts:
        
        norm_words = [norm_uniq.get(word) for word in text]
        norm_words = [word for word in norm_words if word and word not in stops]
        norm_texts.append(norm_words)
    return norm_texts

# %% [markdown]
# ## Нормализуем наши тектсы.
#
# К сожалению, это занимает достаточно много времни, поэтому я сохраняю результат работы, чтобы не запускать процесс заново.

# %%
# %%time
with open('habr_texts.txt') as file:
    data = file.read().splitlines()
    
texts = [normalize(text) for text in data]
# Out:
# CPU times: user 7 µs, sys: 2 µs, total: 9 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 1e+03 ns, total: 7 µs
# Wall time: 11.9 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 9 µs, sys: 2 µs, total: 11 µs
# Wall time: 20 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 1e+03 ns, total: 7 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 1e+03 ns, total: 7 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 4 µs, total: 7 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 2 µs, total: 7 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 8.82 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 13.1 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11.9 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 8.82 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 8 µs, sys: 2 µs, total: 10 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 7 µs, sys: 1 µs, total: 8 µs
# Wall time: 16 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11.9 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 8.82 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 7 µs, sys: 1 µs, total: 8 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11.9 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 12.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 2 µs, total: 8 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 8.82 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 8.82 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 11 µs, sys: 8 µs, total: 19 µs
# Wall time: 44.8 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 2 µs, total: 7 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 11.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 2 µs, total: 7 µs
# Wall time: 12.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 2 µs, total: 8 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 7 µs, sys: 1e+03 ns, total: 8 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 8.82 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 2 µs, total: 7 µs
# Wall time: 11.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 7 µs, sys: 2 µs, total: 9 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 7 µs, sys: 1 µs, total: 8 µs
# Wall time: 26 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 7 µs, sys: 1e+03 ns, total: 8 µs
# Wall time: 16 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 16 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 7 µs, sys: 1e+03 ns, total: 8 µs
# Wall time: 16 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ...
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 2 µs, total: 8 µs
# Wall time: 14.1 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 2 µs, total: 7 µs
# Wall time: 11.9 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 7 µs, sys: 2 µs, total: 9 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 11.9 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 8.11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 10 µs, sys: 2 µs, total: 12 µs
# Wall time: 23.8 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 38.1 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 2 µs, total: 8 µs
# Wall time: 14.1 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 11.9 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 2 µs, total: 7 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 2 µs, total: 7 µs
# Wall time: 12.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11.9 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 8.82 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 12.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.87 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 5 µs, sys: 1 µs, total: 6 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.2 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 9.06 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 11 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs
# ... NEW TEXT ...
# ... TEXT PARSED ...
# CPU times: user 19min 33s, sys: 12.6 s, total: 19min 46s
# Wall time: 19min 52s

# %%
import pickle


with open('hw2_norm_texts.pickle', 'wb') as f:
    pickle.dump(texts, f)

# %%
# %%time

# для нграммов
ph = gensim.models.Phrases(data, scoring='npmi', threshold=0.4) # threshold можно подбирать
p = gensim.models.phrases.Phraser(ph)
ngrammed_texts = p[texts]
# Out:
# CPU times: user 2min 28s, sys: 679 ms, total: 2min 29s
# Wall time: 2min 30s

# %%
with open('ngrammed_texts.pickle', 'wb') as f:
    pickle.dump(ngrammed_texts, f)

# %%
with open('ngrammed_texts.pickle', 'rb') as f:
    ngrammed_texts = pickle.load(f)

# %% [markdown]
# ### Создаем словарь и формируем корпус

# %%
dictinary = gensim.corpora.Dictionary(ngrammed_texts)
dictinary.filter_extremes(no_above=0.3)
dictinary.compactify()

# %%
print(dictinary)
# Out:
# Dictionary(10000 unique tokens: ['вес_грамм', 'премия', 'ввс', 'дефолтной', 'плав']...)

# %%
corpus = [dictinary.doc2bow(text) for text in ngrammed_texts]

# %%
# %%time

lda = gensim.models.LdaModel(corpus, 200, id2word=dictinary, passes=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# CPU times: user 2min 33s, sys: 38.5 s, total: 3min 11s
# Wall time: 1min 57s

# %%
topics_f = lda.print_topics()

# %% [markdown]
# Теперь сформируем датафрейм, чтобы посмотреть на наши топики ввиде таблицы, с помощью pandas.
#
# Столбцы – топики.

# %%
words1 = []

for word in topics_f:
    result = re.findall('\*"(.*?)"', word[1])
    words1.append(result)

pd.DataFrame(words1).transpose()
# Out:
#            0             1            2            3             4   \
# 0          ия      личность   устройство   скачивание            тз
# 1   интеллект        валюта        режим   управление       коллбек
# 2     прогноз  криптовалюта       гаджет   сертификат       блокнот
# 3      анализ      мышление       флешек      контент         пауза
# 4  перфокарта      характер      консоль        пилот  разнообразие
# 5      подход      биткойна     прошивка    программа          маяк
# 6       сфера       природа      дисплей  обнаружение         поляк
# 7     будущее          рост  подключение        месяц         недра
# 8   программа     трансивер       девайс    установка   перегородка
# 9       лента       молоток   обновление         сайт        ураган
#
#                  5               6            7          8           9   \
# 0            сигнал            язык         мозг    история   программа
# 1           частота         перевод         лицо      вышка        узел
# 2          диапазон           текст      область    реакция        цикл
# 3          стандарт     локализация   активность       укол  инструкция
# 4             канал          символ     изучение  понимание    значение
# 5         помещение      блокировка  изображение       душа  компилятор
# 6       длина_волна           форма         глаз    джейсон       поток
# 7          параметр          строка       сигнал        мир       вызов
# 8  чувствительность  форматирование     развитие     золото      память
# 9            спектр        название         кора     дьявол   обработка
#
#             10         11           12              13                 14  \
# 0    противник  помещение  вычислитель            этап                суд
# 1   член_семья    колонка     оболочка         продукт             январь
# 2    фундамент  кинотеатр    отношение  проектирование              право
# 3       улыбка    пустынь    семейство        прототип          нарушение
# 4         евро  слушатель     алгоритм            опыт               роды
# 5           ес     мнение        время      созревание              юрист
# 6       паника   интерьер       подход          прибор              шарик
# 7        выезд   ландшафт  большинство      инструмент  представительство
# 8  консультант  аннотация        метод          рендёр          апелляция
# 9   тепловизор       звук     операция            рука          финляндия
#
#                15            16           17            18        19
# 0        оператор          ядро         сеть  оборудование      игра
# 1           номер    обновление     интернет        кабель    движок
# 2         абонент  перезагрузка   технология          реле  дизайнер
# 3           связь          патч       доступ          жила     карта
# 4  оператор_связь       подсеть        связь   способность      жанр
# 5            база         дебаг      станция       аппарат     серия
# 6          трафик      новгород  подключение  демонстрация      опыт
# 7           канал         вывод          мир       условие  название
# 8           карта       порядок     развитие    веб-камера   история
# 9           адрес       попытка        квт*ч       инженер  художник

# %% [markdown]
# Можно заметить, что даже так у нас появились хорошо выраженные топики.
#
# Все топики оказались весьма хорошими.
#
# Однако, сделаем еще три попытки, с новыми параметрами.

# %%
# %%time

lda2 = gensim.models.LdaModel(corpus, num_topics=10, id2word=dictinary, passes=5)
# Out:
# CPU times: user 49 s, sys: 581 ms, total: 49.6 s
# Wall time: 50.4 s

# %%
topics = lda2.print_topics()

words2 = []

for word in topics:
    result = re.findall('\*"(.*?)"', word[1])
    words2.append(result)

pd.DataFrame(words2).transpose()
# Out:
#              0                        1                 2                 3  \
# 0       доклад                 реквеста       регистратор  криптовымогатель
# 1    двигатель                     урла          роговица             эванс
# 2   синтезатор                неймспейс                ип           зловред
# 3    автостарт  москва_мини-конференция  видеорегистратор        вымогатель
# 4        слайд            дмитрий_жемер             енвда             судок
# 5  температура                   стилус               ооо            тачбар
# 6      головка               термопаста             лазер              лока
# 7         кнут         горизонт_событие             взнос             выкуп
# 8        поезд              блокировщик         лентикула           кинозал
# 9     паяльник                ковыряние            хирург      шифровальщик
#
#             4
# 0        файл
# 1        игра
# 2      сервер
# 3  устройство
# 4        сеть
# 5      объект
# 6     браузер
# 7        сайт
# 8      услуга
# 9      запрос

# %%
# %%time

lda3 = gensim.models.LdaModel(corpus, num_topics=10, id2word=dictinary, passes=15)
# Out:
# CPU times: user 2min 3s, sys: 1.13 s, total: 2min 5s
# Wall time: 2min 6s

# %%
topics = lda3.print_topics()

words3 = []

for word in topics:
    result = re.findall('\*"(.*?)"', word[1])
    words3.append(result)

pd.DataFrame(words3).transpose()
# Out:
#             0              1                  2                 3  \
# 0        файл          корея            шорткат  криптовымогатель
# 1        игра          китай               боль            медуза
# 2      сервер         страна            промиса          филамент
# 3        сеть       вакансия  компания-заказчик           зловред
# 4      объект   законопроект              ткань      краудфандинг
# 5  устройство            фсб          пересадка            припой
# 6        сайт          взлом            пациент           зацепка
# 7     браузер          поезд      дискретизация        справочник
# 8      сервис         сделка             спринт            миньон
# 9      запрос  правительство           сетчатка         предзаказ
#
#                  4            5            6            7                 8  \
# 0        автостарт    усилитель       доклад          фас            промис
# 1        арифметик  температура      студент    двигатель          эксплойт
# 2             плис  аккумулятор    олимпиада     метафора  контроллер_домен
# 3        эльдорадо       прибор  электроника        выкуп             алмаз
# 4             фмрт       кабель         кнут    вселенная           покемон
# 5      лингвистика    конвертер       юлмарт    роскосмос   нарушение_право
# 6          кейноут      батарея    технопарк      спутник            транка
# 7            артур       корпус        табло    галактика               риф
# 8           харрис   синтезатор       квеста  предписание             транк
# 9  саша_гольдштейн      яркость      экзамен    неймспейс        эксплойтов
#
#             9
# 0       скина
# 1        кожа
# 2         ген
# 3  1с-битрикс
# 4      клетка
# 5       робот
# 6       пилот
# 7        лапа
# 8  созревание
# 9       сопло

# %%
# %%time

lda4 = gensim.models.LdaModel(corpus, 200, id2word=dictinary, passes=5, alpha='asymmetric')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# CPU times: user 1min 33s, sys: 13.5 s, total: 1min 46s
# Wall time: 1min 18s

# %%
topics = lda4.print_topics()

words4 = []

for word in topics:
    result = re.findall('\*"(.*?)"', word[1])
    words4.append(result)

pd.DataFrame(words4).transpose()
# Out:
#                 0                   1                   2   \
# 0          апстрим                билл                билл
# 1      дистрибутив           инспектор           инспектор
# 2  санкт-петербург         чтение_губа         чтение_губа
# 3      конференция     переопределение     переопределение
# 4             ядро         разделитель         разделитель
# 5           россия                4-го                4-го
# 6       экосистема  windows-приложение  windows-приложение
# 7          область              библия              библия
# 8             блог           согласный           согласный
# 9           утилит                вирт                вирт
#
#                    3              4              5                 6   \
# 0                билл           хост         проход  консультирование
# 1           инспектор         сервер         спрайт   сосуществование
# 2         чтение_губа       политика          атлас       консультант
# 3     переопределение           дата      отрисовка             рынок
# 4         разделитель         машина         объект        инвестиция
# 5                4-го           ключ       текстура             живой
# 6  windows-приложение  администратор          сцена           сегмент
# 7              библия          центр    преломление       привлечение
# 8           согласный           файл    оптимизация            клиент
# 9                вирт    целостность  профилировщик             актив
#
#                    7                   8              9              10  \
# 0                билл                билл       зачистка          хабов
# 1           инспектор           инспектор          хакер           плис
# 2         чтение_губа         чтение_губа  злоумышленник     отчисление
# 3     переопределение     переопределение        перебор       джойстик
# 4         разделитель         разделитель         сервер       геймпада
# 5                4-го                4-го  администратор         осанка
# 6  windows-приложение  windows-приложение          атака  радиотелескоп
# 7              библия              библия      бухгалтер       кент_бек
# 8           согласный           согласный          бекап   сборка_мусор
# 9                вирт                вирт         пароль         брелок
#
#                   11             12                 13              14  \
# 0         1с-битрикс      ковыряние             медуза   дискретизация
# 1          технопарк        полифил      напряжённость   робот-пылесос
# 2          технотрек          смета           маппинга         пылесос
# 3     информатизация         казань           паранойя  неизменяемость
# 4            кейноут     dom-дерево  ориентированность          уборка
# 5    саша_гольдштейн           соус              брешь             ким
# 6           настойка  показ_реклама   мышка_клавиатура     антипаттерн
# 7     сосредоточение       параноик            печение         аудитор
# 8  юнит-тестирование    блокировщик          друг-друг          учётки
# 9      клиент-сервер       дроссель         субстанция          ключик
#
#                                  15                  16           17  \
# 0                      законопроект                твит      торрент
# 1                               фас    продакт-менеджер        квт*ч
# 2                       предписание                 тен         роут
# 3                              лапа        размер_шрифт       паблик
# 4                          артемьев       перемешивание      вьюпорт
# 5                          степанов              кол-ве  магнитометр
# 6                      топ-менеджер               перец      паскаль
# 7                             майер        наклон_голов          тур
# 8  восстановление_работоспособность              даллас     стирание
# 9                          экспонат  сокращение_затрата   экзоскелет
#
#             18          19
# 0    олимпиада        файл
# 1        скина        игра
# 2   синтезатор      сервер
# 3     младенец  устройство
# 4        эванс        сеть
# 5     паяльник      объект
# 6       репост     браузер
# 7       директ        сайт
# 8      промиса      услуга
# 9  размножение      запрос

# %% [markdown]
# ## Результаты LDA без TfIDF
#
# Наилучшей оказалась модель с параметрами (num_topics=200, id2word=dictinary, passes=5)
#
# Если говорить о топ 3 топиках, то я выбираю:

# %%
print('– Topic words:\n\n{}\n\n– Model print:\n\n{}'.format(words1[5], topics_f[5]))
# Out:
# – Topic words:
#
# ['сигнал', 'частота', 'диапазон', 'стандарт', 'канал', 'помещение', 'длина_волна', 'параметр', 'чувствительность', 'спектр']
#
# – Model print:
#
# (149, '0.137*"сигнал" + 0.057*"частота" + 0.051*"диапазон" + 0.047*"стандарт" + 0.018*"канал" + 0.016*"помещение" + 0.016*"длина_волна" + 0.014*"параметр" + 0.014*"чувствительность" + 0.013*"спектр"')

# %%
print('– Topic words:\n\n{}\n\n– Model print:\n\n{}'.format(words1[15], topics_f[15]))
# Out:
# – Topic words:
#
# ['оператор', 'номер', 'абонент', 'связь', 'оператор_связь', 'база', 'трафик', 'канал', 'карта', 'адрес']
#
# – Model print:
#
# (157, '0.097*"оператор" + 0.089*"номер" + 0.054*"абонент" + 0.035*"связь" + 0.031*"оператор_связь" + 0.025*"база" + 0.023*"трафик" + 0.022*"канал" + 0.021*"карта" + 0.014*"адрес"')

# %%
print('– Topic words:\n\n{}\n\n– Model print:\n\n{}'.format(words1[19], topics_f[19]))
# Out:
# – Topic words:
#
# ['игра', 'движок', 'дизайнер', 'карта', 'жанр', 'серия', 'опыт', 'название', 'история', 'художник']
#
# – Model print:
#
# (121, '0.167*"игра" + 0.017*"движок" + 0.014*"дизайнер" + 0.012*"карта" + 0.011*"жанр" + 0.009*"серия" + 0.009*"опыт" + 0.008*"название" + 0.008*"история" + 0.008*"художник"')

# %% [markdown]
# _____

# %%
tfidf = gensim.models.TfidfModel(corpus, id2word=dictinary)
corpus = tfidf[corpus]

# %%
# %%time

lsi_tfidf = gensim.models.LdaModel(corpus, 200, id2word=dictinary, passes=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# CPU times: user 1min 17s, sys: 1.75 s, total: 1min 19s
# Wall time: 1min 19s

# %%
lsi_tfidf.print_topics()
# Out:
# [(142,
#   '0.039*"разведчик" + 0.034*"дешевизна" + 0.031*"укол" + 0.018*"алмаз" + 0.015*"онлайн-трансляция" + 0.015*"запутанность" + 0.013*"доза" + 0.013*"1990-е" + 0.011*"биотехнология" + 0.010*"гребенка"'),
#  (15,
#   '0.112*"выкуп" + 0.081*"биткоин" + 0.054*"жертва" + 0.043*"заражение" + 0.043*"фбр" + 0.036*"преступник" + 0.018*"зависть" + 0.010*"троян" + 0.008*"атака" + 0.008*"почтальон"'),
#  (5,
#   '0.102*"младенец" + 0.053*"контекст" + 0.049*"неймспейс" + 0.046*"подписка" + 0.027*"припой" + 0.021*"буферы" + 0.018*"веб-браузер" + 0.017*"воспоминание" + 0.016*"транскрипта" + 0.016*"вознаграждение"'),
#  (66,
#   '0.167*"атрибут" + 0.029*"дескриптор" + 0.028*"итератор" + 0.020*"опоздание" + 0.017*"лиза" + 0.014*"аромат" + 0.014*"зачёт" + 0.013*"возврат" + 0.012*"запах" + 0.012*"фонарь"'),
#  (150,
#   '0.012*"недостаточность" + 0.004*"арбитраж" + 0.004*"тир" + 0.003*"usb-порт" + 0.000*"прибавка" + 0.000*"развёртывание" + 0.000*"увольнение" + 0.000*"привязанность" + 0.000*"обочина" + 0.000*"зарплата"'),
#  (103,
#   '0.179*"автостарт" + 0.037*"расстановка" + 0.023*"нелинейность" + 0.020*"примитив" + 0.014*"машинка" + 0.012*"гармоника" + 0.011*"наложение" + 0.009*"искажение" + 0.009*"тесло" + 0.009*"птица"'),
#  (53,
#   '0.016*"it-специалист" + 0.016*"ядро" + 0.016*"ос" + 0.015*"сигнал" + 0.015*"частота" + 0.014*"стандарт" + 0.012*"драйвер" + 0.012*"коммутатор" + 0.012*"источник" + 0.012*"комната"'),
#  (127,
#   '0.039*"калибровка" + 0.032*"индикатор" + 0.030*"экструдер" + 0.027*"крупица" + 0.025*"гайка" + 0.023*"несовместимость" + 0.023*"полпути" + 0.021*"таска" + 0.013*"таск" + 0.013*"парсито"'),
#  (77,
#   '0.218*"игра" + 0.102*"игрок" + 0.026*"жанр" + 0.016*"механик" + 0.015*"костя" + 0.014*"родитель" + 0.013*"девушка" + 0.013*"турнир" + 0.012*"сын" + 0.012*"симулятор"'),
#  (38,
#   '0.146*"веб-сервер" + 0.037*"url-адрес" + 0.035*"плис" + 0.022*"http-сервер" + 0.014*"композиция" + 0.014*"веб-приложение" + 0.011*"мигание" + 0.010*"шланг" + 0.009*"заговор" + 0.008*"скафандр"'),
#  (16,
#   '0.066*"подкаста" + 0.034*"астероид" + 0.024*"зонд" + 0.024*"нил" + 0.019*"парадокс" + 0.016*"взятие" + 0.016*"колодка" + 0.015*"спорт" + 0.014*"шашка" + 0.014*"смерть"'),
#  (11,
#   '0.119*"вкладка" + 0.034*"сестра" + 0.027*"инсайт" + 0.027*"существительное" + 0.023*"полифил" + 0.023*"ивента" + 0.022*"перетаскивание" + 0.020*"распечатка" + 0.018*"столик" + 0.015*"дискриминация"'),
#  (171,
#   '0.052*"вымогатель" + 0.045*"60-е" + 0.036*"шифровальщик" + 0.034*"дядя" + 0.032*"накопитель" + 0.029*"бактерия" + 0.012*"флёша-память" + 0.011*"расшифровка" + 0.010*"ядро" + 0.010*"микроб"'),
#  (1,
#   '0.163*"мастер-класс" + 0.061*"татьяна" + 0.026*"паранойя" + 0.025*"сергей" + 0.018*"dom-дерево" + 0.018*"язык" + 0.016*"рамка" + 0.016*"продюсер" + 0.015*"символ" + 0.014*"конкурентность"'),
#  (26,
#   '0.048*"транспортировка" + 0.042*"экстремум" + 0.033*"антипаттерн" + 0.024*"определённость" + 0.018*"моргание" + 0.018*"велосипед" + 0.017*"медлительность" + 0.017*"константа" + 0.013*"педаль" + 0.012*"подлинность"'),
#  (168,
#   '0.054*"марс" + 0.041*"орбита" + 0.036*"наса" + 0.032*"аппарат" + 0.032*"земля" + 0.030*"полёт" + 0.030*"планета" + 0.029*"луна" + 0.027*"миссия" + 0.025*"кислород"'),
#  (42,
#   '0.099*"майнинга" + 0.056*"сервис-провайдер" + 0.034*"бандло" + 0.033*"ярлык" + 0.032*"больница" + 0.025*"добыча" + 0.021*"капитал" + 0.019*"рак" + 0.018*"опухоль" + 0.016*"скелет"'),
#  (119,
#   '0.044*"успокоение" + 0.023*"проектор" + 0.023*"столп" + 0.022*"кинотеатр" + 0.020*"вечерня" + 0.016*"кардиостимулятор" + 0.013*"web-сервис" + 0.013*"юпитер" + 0.013*"форум" + 0.012*"html-код"'),
#  (49,
#   '0.047*"письмо" + 0.035*"юрлицо" + 0.035*"рассылка" + 0.033*"подписчик" + 0.029*"отправитель" + 0.016*"получатель" + 0.016*"поддомен" + 0.013*"майкрософт" + 0.010*"грипп" + 0.006*"домен"'),
#  (121,
#   '0.008*"звук" + 0.007*"рост" + 0.007*"умолчание" + 0.007*"макрос" + 0.007*"рынок" + 0.007*"интеграция" + 0.006*"точка" + 0.006*"выбор" + 0.006*"клавиатура" + 0.006*"технология"')]

# %%
pyLDAvis.enable_notebook()

# %%
pyLDAvis.gensim.prepare(lsi, corpus, dictinary)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
import numpy as np

# %%
lsi.log_perplexity(corpus[:2000], total_docs=100)
# Out:
# -21.913321441515681

# %%
coherence_model_lda = gensim.models.CoherenceModel(model=lsi, 
                                                   texts=texts, 
                                                   dictionary=dictinary, coherence='c_v')

# %%
topics = []
for topic_id, topic in lsi.show_topics(num_topics=100, formatted=False):
    topic = [word for word, _ in topic]
    topics.append(topic)

# %%
coherence_model_lda = gensim.models.CoherenceModel(topics=topics, 
                                                   texts=texts, 
                                                   dictionary=dictinary, coherence='c_v')

# %%
coherence_model_lda.get_coherence()
# Out:
# 0.47037448946170779

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %%
stexts = [' '.join(text) for text in texts]

# %%
vectorizer = TfidfVectorizer(max_features=25000, min_df=5, max_df=0.3, lowercase=False)
X = vectorizer.fit_transform(stexts)

# %% [markdown]
# ______

# %%
model = NMF(n_components=30)
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=30, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0)

# %%
def get_nmf_topics(model, n_top_words):
    
    #id слов.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(30):
        
        #топ n слов для темы.
        words_ids = model.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
get_nmf_topics(model, 10)
# Out:
#   Topic # 01  Topic # 02   Topic # 03  Topic # 04     Topic # 05  Topic # 06  \
# 0    продукт        игра       модуль       класс     устройство        файл
# 1     бизнес       игрок        пакет      объект         датчик       папка
# 2     клиент    персонаж       плагин       метод       смартфон      скрипт
# 3      рынок      движок       сборка       вызов         сигнал  директория
# 4  сотрудник        жанр    поддержка    свойство     управление      строка
# 5    продажа    геймплей         ядро  реализация  производитель   программа
# 6     деньга        инди  репозиторий   экземпляр         девайс   настройка
# 7    стартап   приставка    установка   интерфейс     технология      сборка
# 8      товар  реальность        релиз  библиотека         гаджет        флаг
# 9      рубль      геймер  зависимость    значение          плата     каталог
#
#    Topic # 07          Topic # 08     Topic # 09 Topic # 10     ...       \
# 0        сайт                диск     уязвимость    спутник     ...
# 1    страница              память          атака     орбита     ...
# 2     браузер           процессор   безопасность     ракета     ...
# 3         веб                ядро  злоумышленник       марс     ...
# 4     реклама  производительность         защита    аппарат     ...
# 5     контент          накопитель     обновление      земля     ...
# 6      ссылка                  гб         пароль    станция     ...
# 7     вкладка              машина         угроза      полёт     ...
# 8       домен           компьютер         доступ       наса     ...
# 9  расширение              запись  исследователь       луна     ...
#
#      Topic # 21  Topic # 22   Topic # 23    Topic # 24      Topic # 25  \
# 0        сервер      запрос       камера       принтер  инфраструктура
# 1        клиент     таблица     смартфон        печать           центр
# 2     настройка        база      телефон            3d            дата
# 3         домен      запись         звук        станок          облако
# 4  конфигурация          бд        экран       пластик          услуга
# 5        машина      индекс      дисплей      материал    оборудование
# 6         адрес        субд        видео  производство          сервис
# 7          база      строка           гб        модель              ит
# 8     контейнер       ответ         цена        деталь       провайдер
# 9          хост  выполнение  аккумулятор       изделие      технология
#
#      Topic # 26     Topic # 27 Topic # 28      Topic # 29   Topic # 30
# 0       пациент          робот       сеть            ключ    сообщение
# 1          мозг        ребёнок     трафик      сертификат       сервис
# 2        клетка         датчик   интернет          пароль       клиент
# 3   заболевание  робототехника      связь           токен       письмо
# 4  исследование         машина      адрес      шифрование     отправка
# 5          врач       движение   оператор         подпись     рассылка
# 6       болезнь     автомобиль     доступ  аутентификация  уведомление
# 7           ген           дрон   протокол          запись        канал
# 8       лечение          набор      точка          доступ      событие
# 9        учёный    манипулятор      канал           домен        почта
#
# [10 rows x 30 columns]
